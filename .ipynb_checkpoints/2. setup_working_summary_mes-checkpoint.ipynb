# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
import matplotlib.ticker as mtick
import os
import platform
import glob

# %%
if platform.system()=='Windows': 
    #Directorios Windows
    os.chdir(
        r"G:\.shortcut-targets-by-id\120bUa35y3FJzvumWahpOx1qS9I6TIrhb\GIGANAV")

if platform.system()=='Darwin':
    os.chdir(
        '/Users/juliandiazparra/Library/CloudStorage/GoogleDrive-julian.adiaz@hotmail.com/Mi unidad/Negocios/Familiar/GIGANAV')

folder=os.getcwd()
data=os.path.join(folder,'Datos')
provisiones=os.path.join(data,'Provisiones')
facturas=os.path.join(data,'Facturas')
tickets=os.path.join(data,'Tickets')
usuarios=os.path.join(data,'Usuarios')
egresos=os.path.join(data,'Egresos')
transacciones=os.path.join(data,'Transacciones')
analisis=os.path.join(folder,'Operacion/Analisis')
resultados=os.path.join(analisis,'Resultados')
bases=os.path.join(analisis,'Bases_analisis')
outputs=os.path.join(analisis,'Outputs')
plots=os.path.join(outputs,'Gráficos')
usuarios_clean=os.path.join(bases,'Usuarios')
transac_clean=os.path.join(bases,'Transacciones')
tickets_clean=os.path.join(bases,'Tickets')
facturas_clean=os.path.join(bases,'Facturas')
egresos_clean=os.path.join(bases,'Egresos')
working=os.path.join(bases,'Bases_trabajo')
codigo=os.path.join(folder,'Operacion/Analisis/Código')
conciliaciones=os.path.join(folder,'Operacion/Operativo/Administrativo/Conciliaciones')

# %% [markdown]
# ## Importación base de trabajo

# %%
list_of_files = glob.glob(os.path.join(outputs,'Base_tickets*.csv'))
latest_file = max(list_of_files, key=os.path.getctime)
working_data=pd.read_csv(latest_file, low_memory=False)
working_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16080 entries, 0 to 16079
# Data columns (total 70 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             16080 non-null  int64
#  1   id_ticket              16080 non-null  int64
#  2   departamento           16080 non-null  object
#  3   nombre                 16080 non-null  object
#  4   asunto                 16080 non-null  object
#  5   tecnico                16080 non-null  object
#  6   zona                   16040 non-null  object
#  7   abierto_por            16080 non-null  object
#  8   instal                 16080 non-null  int64
#  9   soporte                16080 non-null  int64
#  10  traslado               16080 non-null  int64
#  11  retiro                 16080 non-null  int64
#  12  mantenimiento          16080 non-null  int64
#  13  facturacion            16080 non-null  int64
#  14  cambio_plan            16080 non-null  int64
#  15  suspendido             16080 non-null  int64
#  16  tv                     16080 non-null  int64
#  17  llamada                16080 non-null  int64
#  18  categoria              15063 non-null  object
#  19  fecha_abierto          16080 non-null  object
#  20  fecha_cerrado          16080 non-null  object
#  21  mes_crd                16080 non-null  object
#  22  first_day              16080 non-null  object
#  23  tiempo_resolucion      16080 non-null  object
#  24  cat_tecnico            15063 non-null  float64
#  25  comercial              15063 non-null  float64
#  26  Id                     16080 non-null  int64
#  27  estado                 16080 non-null  object
#  28  radio                  16080 non-null  int64
#  29  Tipo estrato           16080 non-null  int64
#  30  megas                  16080 non-null  int64
#  31  TV                     16080 non-null  int64
#  32  Telefono               12203 non-null  object
#  33  Movil                  15989 non-null  object
#  34  Correo                 12405 non-null  object
#  35  Zona                   16040 non-null  object
#  36  tarifa                 16080 non-null  float64
#  37  Deuda actual           4901 non-null   object
#  38  ID de registro         16022 non-null  float64
#  39  meses_suspendido       1548 non-null   float64
#  40  deuda                  1548 non-null   float64
#  41  tecnologia             16080 non-null  object
#  42  tipo_servicio          16080 non-null  object
#  43  tipo_usuario           16080 non-null  object
#  44  _merge                 16080 non-null  object
#  45  tecnico_1              1915 non-null   object
#  46  tecnico_2              341 non-null    object
#  47  conector_mecanico      1915 non-null   float64
#  48  fibra_drop             1915 non-null   float64
#  49  conector_coaxial       1915 non-null   float64
#  50  tensores               1915 non-null   float64
#  51  cable_coaxial          1915 non-null   float64
#  52  cable_utp              1915 non-null   float64
#  53  rjs                    1915 non-null   float64
#  54  deco_tdt               1915 non-null   float64
#  55  splitter_2             1915 non-null   float64
#  56  splitter_3             1915 non-null   float64
#  57  splitter_4             1915 non-null   float64
#  58  mininodos              1915 non-null   float64
#  59  otros                  1915 non-null   float64
#  60  merge2                 16080 non-null  object
#  61  fecha_enc_sat          104 non-null    object
#  62  calificacion_personal  104 non-null    float64
#  63  resolvio               104 non-null    float64
#  64  promoter               104 non-null    float64
#  65  calificacion_servicio  75 non-null     float64
#  66  merge_sat              16080 non-null  object
#  67  encuesta               16080 non-null  bool
#  68  residencial            16080 non-null  int64
#  69  tiempo_resol           16080 non-null  float64
# dtypes: bool(1), float64(24), int64(18), object(27)
# memory usage: 8.5+ MB

# %%
#Analisis categoria solicitud tipo de cliente
working_data.loc[working_data['cat_tecnico']==1].groupby(
    ['mes_crd','tipo_servicio','categoria']).agg(
    num_tickets=('id_ticket','nunique'), 
    tiempo_respuesta=('tiempo_resol',pd.Series.median)
).reset_index()
# Out:
#      mes_crd tipo_servicio    categoria  num_tickets  tiempo_respuesta
# 0    2022-01   corporativo  Instalacion            2          0.010098
# 1    2022-01   corporativo       Retiro            3          1.858322
# 2    2022-01   corporativo      Soporte           12          0.099826
# 3    2022-01   residencial  Instalacion           72          0.621007
# 4    2022-01   residencial       Retiro           68          0.002708
# ..       ...           ...          ...          ...               ...
# 234  2024-10   corporativo      Soporte            1          0.150625
# 235  2024-10   residencial  Instalacion           24          3.118646
# 236  2024-10   residencial       Retiro           16          2.731256
# 237  2024-10   residencial      Soporte           58          1.010266
# 238  2024-10   residencial     Traslado           13          2.906944
#
# [239 rows x 5 columns]

# %%
#analisis residencia/empresa
summary_res_emp=working_data.loc[working_data['cat_tecnico']==1].groupby(
    ['mes_crd','tipo_servicio','categoria']).agg(
    num_tickets=('id_ticket','nunique'), 
    tiempo_respuesta=('tiempo_resol',pd.Series.mean)).reset_index().pivot(
    index='mes_crd',columns=[
        'categoria','tipo_servicio'], 
    values=['num_tickets',
           'tiempo_respuesta']).reset_index()
summary_res_emp.tail()
# Out:
#                mes_crd num_tickets                                      \
# categoria              Instalacion      Retiro     Soporte Instalacion
# tipo_servicio          corporativo corporativo corporativo residencial
# 29             2024-06         3.0         3.0         7.0       197.0
# 30             2024-07         5.0         3.0         6.0       189.0
# 31             2024-08         6.0         NaN         7.0        73.0
# 32             2024-09         1.0         3.0        11.0        93.0
# 33             2024-10         NaN         1.0         1.0        24.0
#
#                                                                \
# categoria          Retiro     Soporte    Traslado
# tipo_servicio residencial residencial residencial corporativo
# 29                   33.0       155.0        23.0         2.0
# 30                   48.0       198.0        29.0         1.0
# 31                   44.0       227.0        27.0         NaN
# 32                   49.0       390.0        28.0         1.0
# 33                   16.0        58.0        13.0         NaN
#
#               tiempo_respuesta                                      \
# categoria          Instalacion      Retiro     Soporte Instalacion
# tipo_servicio      corporativo corporativo corporativo residencial
# 29                    3.017238    6.009931    3.333712    4.245590
# 30                    4.163579   27.975448    3.105635    5.448586
# 31                    2.836408         NaN    0.299797    3.036249
# 32                    1.627546    2.139078    1.591901    1.971909
# 33                         NaN    3.822998    0.150625    3.200026
#
#
# categoria          Retiro     Soporte    Traslado
# tipo_servicio residencial residencial residencial corporativo
# 29               6.160829    5.130114    4.599576    3.759155
# 30               6.022392    5.875019    6.080024    1.060023
# 31               4.567179    2.696308    3.632554         NaN
# 32               3.420593    1.948224    2.897211   23.384861
# 33               4.781947    2.062724    2.543724         NaN

# %%
#Analisis TV o internet
summary_int_tv=working_data.loc[working_data['cat_tecnico']==1].groupby(
    ['mes_crd','tipo_usuario','categoria']).agg(
    num_tickets=('id_ticket','nunique'), 
    tiempo_respuesta=('tiempo_resol',pd.Series.mean)).reset_index().pivot(
    index='mes_crd',columns=[
        'categoria','tipo_usuario'], 
    values=['num_tickets',
           'tiempo_respuesta']).reset_index()
summary_int_tv.tail(10)
# Out:
#               mes_crd num_tickets                                         \
# categoria             Instalacion   Retiro  Soporte Traslado Instalacion
# tipo_usuario             internet internet internet internet     paquete
# 24            2024-01        65.0     29.0    131.0     26.0        27.0
# 25            2024-02        59.0     32.0    189.0     18.0        27.0
# 26            2024-03        50.0     49.0     95.0     24.0        44.0
# 27            2024-04        61.0     33.0    114.0     23.0        28.0
# 28            2024-05        44.0     29.0    106.0     13.0        28.0
# 29            2024-06       112.0     24.0     96.0     19.0        88.0
# 30            2024-07       102.0     33.0    115.0     26.0        92.0
# 31            2024-08        57.0     25.0    135.0     18.0        21.0
# 32            2024-09        89.0     32.0    253.0     23.0         5.0
# 33            2024-10        24.0      9.0     42.0      9.0         NaN
#
#                                       tiempo_respuesta                       \
# categoria     Retiro Soporte Traslado      Instalacion     Retiro   Soporte
# tipo_usuario paquete paquete  paquete         internet   internet  internet
# 24              15.0    63.0     12.0         2.264263   4.211128  4.701560
# 25              27.0   115.0     12.0         2.799418   2.065219  7.999967
# 26              23.0    67.0      3.0         3.468160   5.473945  2.384105
# 27              31.0    71.0     19.0         4.217723   5.537637  4.142874
# 28              20.0    52.0      6.0         4.404782   8.455724  5.831084
# 29              12.0    65.0      5.0         4.589041   5.505130  5.199979
# 30              17.0    89.0      4.0         5.710632  10.118946  5.710626
# 31              19.0    98.0      9.0         3.022821   3.709269  2.901963
# 32              21.0   150.0      6.0         1.881777   4.481856  2.006159
# 33               7.0    17.0      4.0         3.200026   4.251486  2.100347
#
#
# categoria     Traslado Instalacion    Retiro   Soporte   Traslado
# tipo_usuario  internet     paquete   paquete   paquete    paquete
# 24            3.258926    3.124904  0.808924  3.410740   3.946453
# 25            3.421510    3.036322  5.662548  8.333026   6.255343
# 26            3.152265    3.180928  2.268668  3.316309   3.874761
# 27            4.318911   12.336203  5.482025  5.875028   6.257143
# 28            5.817247    5.101982  2.268082  7.074129   3.462700
# 29            4.524534    3.752194  7.434504  4.838337   4.563576
# 30            5.106210    5.091565  1.703352  5.903472  11.641722
# 31            3.926157    3.017520  5.741160  2.244747   3.045349
# 32            3.613212    3.561470  1.605706  1.824532   3.447814
# 33            2.393358         NaN  5.402756  1.860348   2.882049

# %%
summary_fibra_radio=working_data.loc[
    working_data['cat_tecnico']==1].groupby(
    ['mes_crd', 'categoria', 'tecnologia']).agg(
    tiempo_respuesta=('tiempo_resol',pd.Series.mean), 
    num_tickets=('id_ticket', 'nunique'), 
    encuestas=('encuesta', 'sum')).reset_index().pivot(
    index='mes_crd', columns=[
        'categoria', 'tecnologia'], values=[
        'tiempo_respuesta', 'num_tickets', 'encuestas'
    ]).reset_index()

summary_fibra_radio.tail()
# Out:
#             mes_crd tiempo_respuesta                                          \
# categoria                Instalacion              Retiro             Soporte
# tecnologia                     fibra     radio     fibra     radio     fibra
# 29          2024-06         4.241618  4.210674  6.580995  3.465262  5.284792
# 30          2024-07         4.952676  6.155529  7.164182  8.435490  5.473163
# 31          2024-08         3.374170  2.724837  4.728704  2.911545  2.282151
# 32          2024-09         2.627447  1.875311  2.883235  4.902272  1.807004
# 33          2024-10              NaN  3.200026  3.922664  8.472288  1.740564
#
#                                          num_tickets  ...                 \
# categoria             Traslado           Instalacion  ... Traslado
# tecnologia     radio     fibra     radio       fibra  ...    fibra radio
# 29          4.762400  4.972402  4.238969       115.0  ...     10.0  15.0
# 30          6.205463  7.210770  5.042145       116.0  ...     12.0  18.0
# 31          3.012452  2.888437  4.227849        36.0  ...     12.0  15.0
# 32          2.035962  5.389422  2.532649        12.0  ...     11.0  18.0
# 33          2.175591  2.882049  2.393358         NaN  ...      4.0   9.0
#
#              encuestas
# categoria  Instalacion       Retiro       Soporte       Traslado
# tecnologia       fibra radio  fibra radio   fibra radio    fibra radio
# 29                98.0  83.0    5.0   0.0    42.0  34.0      8.0  15.0
# 30                90.0  56.0    1.0   0.0    15.0  10.0      5.0   9.0
# 31                13.0  19.0    3.0   3.0    62.0  49.0      6.0   7.0
# 32                10.0  66.0   10.0   5.0    54.0  98.0      5.0  16.0
# 33                 NaN  20.0   10.0   1.0    19.0  38.0      3.0   9.0
#
# [5 rows x 25 columns]

# %%
summary_encuesta_cat=working_data.loc[
    working_data['cat_tecnico']==1
].groupby([
    'mes_crd','categoria'
]).agg(num_tickets=(
    'id_ticket','nunique'), 
       encuesta=(
           'encuesta','sum')).reset_index().pivot(
    columns='categoria',
    index='mes_crd',values=[
        'num_tickets',
        'encuesta']).reset_index()

for i in ['Instalacion','Retiro','Soporte','Traslado']:
    summary_encuesta_cat.loc[
        :,'per_enc_'+i]=summary_encuesta_cat[
        ('encuesta',i)]/summary_encuesta_cat[
        ('num_tickets',i)]
summary_encuesta_cat=summary_encuesta_cat.iloc[:,np.r_[0,-4:0]]

nombre_columnas=[]
for i, x in enumerate(list(summary_encuesta_cat.columns)):
    nombre_columnas.append(x[0])

summary_encuesta_cat.columns=nombre_columnas
summary_encuesta_cat.tail()
# Out:
#     mes_crd  per_enc_Instalacion  per_enc_Retiro  per_enc_Soporte  \
# 29  2024-06             0.905000        0.138889         0.472050
# 30  2024-07             0.764398        0.020000         0.124378
# 31  2024-08             0.415584        0.136364         0.478448
# 32  2024-09             0.808511        0.288462         0.382872
# 33  2024-10             0.833333        0.687500         0.966102
#
#     per_enc_Traslado
# 29          0.958333
# 30          0.466667
# 31          0.481481
# 32          0.724138
# 33          0.923077

# %%
for i in [summary_int_tv,summary_fibra_radio,summary_res_emp,]:
    nombres_columnas=[]
    for k, x  in enumerate(list(i.columns)):            
        nombres_columnas.append('_'.join([str(j) for j in list(x)]))
    i.columns=nombres_columnas
    i.rename(columns={'mes_crd__':'mes_crd'}, inplace=True)

# %%
working_summary=summary_fibra_radio.merge(
    summary_int_tv, on='mes_crd',how='inner').merge(
    summary_res_emp, on='mes_crd',how='inner').merge(
    summary_encuesta_cat, on='mes_crd',how='inner')
working_summary.tail()
# Out:
#     mes_crd  tiempo_respuesta_Instalacion_fibra  \
# 29  2024-06                            4.241618
# 30  2024-07                            4.952676
# 31  2024-08                            3.374170
# 32  2024-09                            2.627447
# 33  2024-10                                 NaN
#
#     tiempo_respuesta_Instalacion_radio  tiempo_respuesta_Retiro_fibra  \
# 29                            4.210674                       6.580995
# 30                            6.155529                       7.164182
# 31                            2.724837                       4.728704
# 32                            1.875311                       2.883235
# 33                            3.200026                       3.922664
#
#     tiempo_respuesta_Retiro_radio  tiempo_respuesta_Soporte_fibra  \
# 29                       3.465262                        5.284792
# 30                       8.435490                        5.473163
# 31                       2.911545                        2.282151
# 32                       4.902272                        1.807004
# 33                       8.472288                        1.740564
#
#     tiempo_respuesta_Soporte_radio  tiempo_respuesta_Traslado_fibra  \
# 29                        4.762400                         4.972402
# 30                        6.205463                         7.210770
# 31                        3.012452                         2.888437
# 32                        2.035962                         5.389422
# 33                        2.175591                         2.882049
#
#     tiempo_respuesta_Traslado_radio  num_tickets_Instalacion_fibra  ...  \
# 29                         4.238969                          115.0  ...
# 30                         5.042145                          116.0  ...
# 31                         4.227849                           36.0  ...
# 32                         2.532649                           12.0  ...
# 33                         2.393358                            NaN  ...
#
#     tiempo_respuesta_Soporte_corporativo  \
# 29                              3.333712
# 30                              3.105635
# 31                              0.299797
# 32                              1.591901
# 33                              0.150625
#
#     tiempo_respuesta_Instalacion_residencial  \
# 29                                  4.245590
# 30                                  5.448586
# 31                                  3.036249
# 32                                  1.971909
# 33                                  3.200026
#
#     tiempo_respuesta_Retiro_residencial  tiempo_respuesta_Soporte_residencial  \
# 29                             6.160829                              5.130114
# 30                             6.022392                              5.875019
# 31                             4.567179                              2.696308
# 32                             3.420593                              1.948224
# 33                             4.781947                              2.062724
#
#     tiempo_respuesta_Traslado_residencial  \
# 29                               4.599576
# 30                               6.080024
# 31                               3.632554
# 32                               2.897211
# 33                               2.543724
#
#     tiempo_respuesta_Traslado_corporativo  per_enc_Instalacion  \
# 29                               3.759155             0.905000
# 30                               1.060023             0.764398
# 31                                    NaN             0.415584
# 32                              23.384861             0.808511
# 33                                    NaN             0.833333
#
#     per_enc_Retiro  per_enc_Soporte  per_enc_Traslado
# 29        0.138889         0.472050          0.958333
# 30        0.020000         0.124378          0.466667
# 31        0.136364         0.478448          0.481481
# 32        0.288462         0.382872          0.724138
# 33        0.687500         0.966102          0.923077
#
# [5 rows x 61 columns]

# %%
filepath=os.path.join(outputs,'Resumen_mes_categorias_tecnicas')
working_summary.to_csv(filepath+'.csv')
