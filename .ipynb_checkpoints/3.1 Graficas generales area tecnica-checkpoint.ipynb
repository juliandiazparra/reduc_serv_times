# %%
#import streamlit as st
#import pandas as pd
#import altair as alt
#import plotly.express as px

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
import matplotlib.ticker as mtick
import os
import platform
import glob

# %%
if platform.system()=='Windows': 
    #Directorios Windows
    os.chdir(
        r"G:\.shortcut-targets-by-id\120bUa35y3FJzvumWahpOx1qS9I6TIrhb\GIGANAV")

if platform.system()=='Darwin':
    os.chdir(
        '/Users/juliandiazparra/Library/CloudStorage/GoogleDrive-julian.adiaz@hotmail.com/Mi unidad/Negocios/Familiar/GIGANAV')

folder=os.getcwd()
data=os.path.join(folder,'Datos')
provisiones=os.path.join(data,'Provisiones')
facturas=os.path.join(data,'Facturas')
tickets=os.path.join(data,'Tickets')
usuarios=os.path.join(data,'Usuarios')
egresos=os.path.join(data,'Egresos')
transacciones=os.path.join(data,'Transacciones')
analisis=os.path.join(folder,'Operacion/Analisis')
resultados=os.path.join(analisis,'Resultados')
bases=os.path.join(analisis,'Bases_analisis')
outputs=os.path.join(analisis,'Outputs')
plots=os.path.join(outputs,'Gráficos')
usuarios_clean=os.path.join(bases,'Usuarios')
transac_clean=os.path.join(bases,'Transacciones')
tickets_clean=os.path.join(bases,'Tickets')
facturas_clean=os.path.join(bases,'Facturas')
egresos_clean=os.path.join(bases,'Egresos')
working=os.path.join(bases,'Bases_trabajo')
codigo=os.path.join(folder,'Operacion/Analisis/Código')
conciliaciones=os.path.join(folder,'Operacion/Operativo/Administrativo/Conciliaciones')

# %% [markdown]
# ## Importación base de trabajo

# %%
list_of_files = glob.glob(os.path.join(outputs,'Resumen_mes_categorias*.csv'))
latest_file = max(list_of_files, key=os.path.getctime)
working_summary=pd.read_csv(latest_file, low_memory=False)
working_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 62 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Unnamed: 0                                34 non-null     int64
#  1   mes_crd                                   34 non-null     object
#  2   tiempo_respuesta_Instalacion_fibra        33 non-null     float64
#  3   tiempo_respuesta_Instalacion_radio        34 non-null     float64
#  4   tiempo_respuesta_Retiro_fibra             34 non-null     float64
#  5   tiempo_respuesta_Retiro_radio             34 non-null     float64
#  6   tiempo_respuesta_Soporte_fibra            34 non-null     float64
#  7   tiempo_respuesta_Soporte_radio            34 non-null     float64
#  8   tiempo_respuesta_Traslado_fibra           34 non-null     float64
#  9   tiempo_respuesta_Traslado_radio           34 non-null     float64
#  10  num_tickets_Instalacion_fibra             33 non-null     float64
#  11  num_tickets_Instalacion_radio             34 non-null     float64
#  12  num_tickets_Retiro_fibra                  34 non-null     float64
#  13  num_tickets_Retiro_radio                  34 non-null     float64
#  14  num_tickets_Soporte_fibra                 34 non-null     float64
#  15  num_tickets_Soporte_radio                 34 non-null     float64
#  16  num_tickets_Traslado_fibra                34 non-null     float64
#  17  num_tickets_Traslado_radio                34 non-null     float64
#  18  encuestas_Instalacion_fibra               33 non-null     float64
#  19  encuestas_Instalacion_radio               34 non-null     float64
#  20  encuestas_Retiro_fibra                    34 non-null     float64
#  21  encuestas_Retiro_radio                    34 non-null     float64
#  22  encuestas_Soporte_fibra                   34 non-null     float64
#  23  encuestas_Soporte_radio                   34 non-null     float64
#  24  encuestas_Traslado_fibra                  34 non-null     float64
#  25  encuestas_Traslado_radio                  34 non-null     float64
#  26  num_tickets_Instalacion_internet          34 non-null     float64
#  27  num_tickets_Retiro_internet               34 non-null     float64
#  28  num_tickets_Soporte_internet              34 non-null     float64
#  29  num_tickets_Traslado_internet             34 non-null     float64
#  30  num_tickets_Instalacion_paquete           33 non-null     float64
#  31  num_tickets_Retiro_paquete                34 non-null     float64
#  32  num_tickets_Soporte_paquete               34 non-null     float64
#  33  num_tickets_Traslado_paquete              34 non-null     float64
#  34  tiempo_respuesta_Instalacion_internet     34 non-null     float64
#  35  tiempo_respuesta_Retiro_internet          34 non-null     float64
#  36  tiempo_respuesta_Soporte_internet         34 non-null     float64
#  37  tiempo_respuesta_Traslado_internet        34 non-null     float64
#  38  tiempo_respuesta_Instalacion_paquete      33 non-null     float64
#  39  tiempo_respuesta_Retiro_paquete           34 non-null     float64
#  40  tiempo_respuesta_Soporte_paquete          34 non-null     float64
#  41  tiempo_respuesta_Traslado_paquete         34 non-null     float64
#  42  num_tickets_Instalacion_corporativo       28 non-null     float64
#  43  num_tickets_Retiro_corporativo            23 non-null     float64
#  44  num_tickets_Soporte_corporativo           34 non-null     float64
#  45  num_tickets_Instalacion_residencial       34 non-null     float64
#  46  num_tickets_Retiro_residencial            34 non-null     float64
#  47  num_tickets_Soporte_residencial           34 non-null     float64
#  48  num_tickets_Traslado_residencial          34 non-null     float64
#  49  num_tickets_Traslado_corporativo          18 non-null     float64
#  50  tiempo_respuesta_Instalacion_corporativo  28 non-null     float64
#  51  tiempo_respuesta_Retiro_corporativo       23 non-null     float64
#  52  tiempo_respuesta_Soporte_corporativo      34 non-null     float64
#  53  tiempo_respuesta_Instalacion_residencial  34 non-null     float64
#  54  tiempo_respuesta_Retiro_residencial       34 non-null     float64
#  55  tiempo_respuesta_Soporte_residencial      34 non-null     float64
#  56  tiempo_respuesta_Traslado_residencial     34 non-null     float64
#  57  tiempo_respuesta_Traslado_corporativo     18 non-null     float64
#  58  per_enc_Instalacion                       34 non-null     float64
#  59  per_enc_Retiro                            34 non-null     float64
#  60  per_enc_Soporte                           34 non-null     float64
#  61  per_enc_Traslado                          34 non-null     float64
# dtypes: float64(60), int64(1), object(1)
# memory usage: 16.6+ KB

# %%
list_of_files = glob.glob(os.path.join(outputs,'Base_tickets*.csv'))
latest_file = max(list_of_files, key=os.path.getctime)
working_data=pd.read_csv(latest_file, low_memory=False)
working_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16080 entries, 0 to 16079
# Data columns (total 70 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             16080 non-null  int64
#  1   id_ticket              16080 non-null  int64
#  2   departamento           16080 non-null  object
#  3   nombre                 16080 non-null  object
#  4   asunto                 16080 non-null  object
#  5   tecnico                16080 non-null  object
#  6   zona                   16040 non-null  object
#  7   abierto_por            16080 non-null  object
#  8   instal                 16080 non-null  int64
#  9   soporte                16080 non-null  int64
#  10  traslado               16080 non-null  int64
#  11  retiro                 16080 non-null  int64
#  12  mantenimiento          16080 non-null  int64
#  13  facturacion            16080 non-null  int64
#  14  cambio_plan            16080 non-null  int64
#  15  suspendido             16080 non-null  int64
#  16  tv                     16080 non-null  int64
#  17  llamada                16080 non-null  int64
#  18  categoria              15063 non-null  object
#  19  fecha_abierto          16080 non-null  object
#  20  fecha_cerrado          16080 non-null  object
#  21  mes_crd                16080 non-null  object
#  22  first_day              16080 non-null  object
#  23  tiempo_resolucion      16080 non-null  object
#  24  cat_tecnico            15063 non-null  float64
#  25  comercial              15063 non-null  float64
#  26  Id                     16080 non-null  int64
#  27  estado                 16080 non-null  object
#  28  radio                  16080 non-null  int64
#  29  Tipo estrato           16080 non-null  int64
#  30  megas                  16080 non-null  int64
#  31  TV                     16080 non-null  int64
#  32  Telefono               12203 non-null  object
#  33  Movil                  15989 non-null  object
#  34  Correo                 12405 non-null  object
#  35  Zona                   16040 non-null  object
#  36  tarifa                 16080 non-null  float64
#  37  Deuda actual           4901 non-null   object
#  38  ID de registro         16022 non-null  float64
#  39  meses_suspendido       1548 non-null   float64
#  40  deuda                  1548 non-null   float64
#  41  tecnologia             16080 non-null  object
#  42  tipo_servicio          16080 non-null  object
#  43  tipo_usuario           16080 non-null  object
#  44  _merge                 16080 non-null  object
#  45  tecnico_1              1915 non-null   object
#  46  tecnico_2              341 non-null    object
#  47  conector_mecanico      1915 non-null   float64
#  48  fibra_drop             1915 non-null   float64
#  49  conector_coaxial       1915 non-null   float64
#  50  tensores               1915 non-null   float64
#  51  cable_coaxial          1915 non-null   float64
#  52  cable_utp              1915 non-null   float64
#  53  rjs                    1915 non-null   float64
#  54  deco_tdt               1915 non-null   float64
#  55  splitter_2             1915 non-null   float64
#  56  splitter_3             1915 non-null   float64
#  57  splitter_4             1915 non-null   float64
#  58  mininodos              1915 non-null   float64
#  59  otros                  1915 non-null   float64
#  60  merge2                 16080 non-null  object
#  61  fecha_enc_sat          104 non-null    object
#  62  calificacion_personal  104 non-null    float64
#  63  resolvio               104 non-null    float64
#  64  promoter               104 non-null    float64
#  65  calificacion_servicio  75 non-null     float64
#  66  merge_sat              16080 non-null  object
#  67  encuesta               16080 non-null  bool
#  68  residencial            16080 non-null  int64
#  69  tiempo_resol           16080 non-null  float64
# dtypes: bool(1), float64(24), int64(18), object(27)
# memory usage: 8.5+ MB

# %% [markdown]
# ## Analisis fibra vs radio

# %%
fig, ax= plt.subplots()

working_summary.iloc[-5:].plot(x='mes_crd', y='tiempo_respuesta_Soporte_fibra', 
                               kind='line', ax=ax, 
                               color='magenta', grid=True)
working_summary.iloc[-5:].plot(x='mes_crd', y='tiempo_respuesta_Instalacion_fibra', 
                             kind='line', ax=ax, 
                               color='blue', grid=True)
working_summary.iloc[-5:].plot(x='mes_crd', y='tiempo_respuesta_Traslado_fibra', 
                             kind='line', ax=ax, 
                               color='grey', grid=True)
working_summary.iloc[-5:].plot(x='mes_crd', y='tiempo_respuesta_Retiro_fibra', 
                             kind='line', ax=ax, 
                               color='purple', grid=True)


plt.setp(ax, ylabel='Días', xlabel='', title='Promedio de tiempo de respuesta: fibra')
ax.legend(['Soporte', 'Instalacion', 'Traslado','Retiro'])
plt.tight_layout()
plt.show()

# %%
summary_tix_fibra_radio=working_data.loc[
    working_data['cat_tecnico']==1].groupby(
    ['mes_crd', 'tecnologia']).agg(
    num_tix=('id_ticket','nunique')).reset_index().pivot(
    columns='tecnologia',
    values='num_tix', 
    index='mes_crd').reset_index()
summary_tix_fibra_radio.columns=['mes_crd','fibra','radio']
summary_tix_fibra_radio.loc[
    :,'porc_fibra'
]=summary_tix_fibra_radio[
    'fibra']/(summary_tix_fibra_radio[
    'fibra']+summary_tix_fibra_radio[
    'radio'])

summary_tix_fibra_radio.loc[
    :,'porc_radio'
]=summary_tix_fibra_radio[
    'radio']/(summary_tix_fibra_radio[
    'fibra']+summary_tix_fibra_radio[
    'radio'])
summary_tix_fibra_radio.tail()
#print('Durante el último trimestre, el '+str(
#    summary_tix_fibra_radio.iloc[-4:-1][
#        'porc_fibra'].mean())+' de tickets fueron de fibra')
# Out:
#     mes_crd  fibra  radio  porc_fibra  porc_radio
# 29  2024-06    249    176    0.585882    0.414118
# 30  2024-07    282    194    0.592437    0.407563
# 31  2024-08    212    172    0.552083    0.447917
# 32  2024-09    231    345    0.401042    0.598958
# 33  2024-10     37     75    0.330357    0.669643

# %%
fig,ax=plt.subplots()
summary_tix_fibra_radio.iloc[-6:-1,:3].plot.bar(
    'mes_crd','fibra',
    ax=ax, #bottom=base, 
    color='lightseagreen', 
    grid=True)
summary_tix_fibra_radio.iloc[-6:-1,:3].plot.bar(
    'mes_crd','radio',
    ax=ax, bottom=summary_tix_fibra_radio.iloc[-6:-1,:3]['fibra'], 
    color='tomato', 
    grid=True)

plt.tight_layout()
plt.show()

# %%
fig, ax=plt.subplots()

working_summary.iloc[-6:].plot(
    x='mes_crd', y='tiempo_respuesta_Soporte_radio', 
    kind='line', ax=ax, 
    color='magenta', grid=True, linestyle='--')

working_summary.iloc[-6:].plot(
    x='mes_crd', y='tiempo_respuesta_Instalacion_radio', 
                               kind='line', ax=ax, 
                               color='blue', grid=True, linestyle='--')

working_summary.iloc[-6:].plot(
    x='mes_crd', y='tiempo_respuesta_Traslado_radio', 
                               kind='line', ax=ax, 
                               color='grey', grid=True, linestyle='--')

working_summary.iloc[-6:].plot(
    x='mes_crd', y='tiempo_respuesta_Retiro_radio', 
                               kind='line', ax=ax, 
                               color='purple', grid=True, linestyle='--')

plt.setp(ax, ylabel='Días', xlabel='', title='Promedio de tiempo de respuesta: radio')
ax.legend(['Soporte', 'Instalacion', 'Traslado','Retiro'])
plt.tight_layout()
plt.show()
