# %%
#import streamlit as st
#import pandas as pd
#import altair as alt
#import plotly.express as px

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
import matplotlib.ticker as mtick
import os
import platform
import glob
import platform

# %%
import getpass

# Obtener el nombre de usuario actual
user = getpass.getuser()

if platform.system() == 'Darwin':
    
    if user == 'juliandiazparra':  # Usuario en el primer Mac
        os.chdir(
            '/Users/juliandiazparra/Library/CloudStorage/GoogleDrive-julian.adiaz@hotmail.com/Mi unidad/Negocios/Familiar/GIGANAV')
        
    elif user == 'usuarioo':  # Nombre del usuario en el segundo Mac
        os.chdir(
            '/Users/usuarioo/Library/CloudStorage/GoogleDrive-julian.adiaz@hotmail.com/Mi unidad/Negocios/Familiar/GIGANAV')

# Definir las rutas como antes
folder = os.getcwd()
data = os.path.join(folder, 'Datos')
provisiones = os.path.join(data, 'Provisiones')
facturas = os.path.join(data, 'Facturas')
tickets = os.path.join(data, 'Tickets')
usuarios = os.path.join(data, 'Usuarios')
egresos = os.path.join(data, 'Egresos')
transacciones = os.path.join(data, 'Transacciones')
analisis = os.path.join(folder, 'Operacion/Analisis')
resultados = os.path.join(analisis, 'Resultados')
bases = os.path.join(analisis, 'Bases_analisis')
outputs = os.path.join(analisis, 'Outputs')
plots = os.path.join(outputs, 'Gráficos')
usuarios_clean = os.path.join(bases, 'Usuarios')
transac_clean = os.path.join(bases, 'Transacciones')
tickets_clean = os.path.join(bases, 'Tickets')
facturas_clean = os.path.join(bases, 'Facturas')
egresos_clean = os.path.join(bases, 'Egresos')
working = os.path.join(bases, 'Bases_trabajo')
codigo = os.path.join(folder, 'Operacion/Analisis/Código')
conciliaciones = os.path.join(folder, 'Operacion/Operativo/Administrativo/Conciliaciones')

# %% [markdown]
# ## Importación base de trabajo

# %%
list_of_files = glob.glob(os.path.join(outputs,'Resumen_mes_categorias*.csv'))
latest_file = max(list_of_files, key=os.path.getctime)
working_summary=pd.read_csv(latest_file, low_memory=False)
working_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 69 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Unnamed: 0                                  34 non-null     int64
#  1   mes_crd                                     34 non-null     object
#  2   tiempo_respuesta_instal_fibra               34 non-null     float64
#  3   tiempo_respuesta_instal_radio               24 non-null     float64
#  4   tiempo_respuesta_retiro_fibra               34 non-null     float64
#  5   tiempo_respuesta_soporte_fibra              34 non-null     float64
#  6   tiempo_respuesta_soporte_radio              34 non-null     float64
#  7   tiempo_respuesta_traslado_fibra             34 non-null     float64
#  8   tiempo_respuesta_traslado_radio             8 non-null      float64
#  9   tiempo_respuesta_retiro_radio               4 non-null      float64
#  10  tiempo_respuesta_mantenimiento_fibra        7 non-null      float64
#  11  num_tickets_instal_fibra                    34 non-null     float64
#  12  num_tickets_instal_radio                    24 non-null     float64
#  13  num_tickets_retiro_fibra                    34 non-null     float64
#  14  num_tickets_soporte_fibra                   34 non-null     float64
#  15  num_tickets_soporte_radio                   34 non-null     float64
#  16  num_tickets_traslado_fibra                  34 non-null     float64
#  17  num_tickets_traslado_radio                  8 non-null      float64
#  18  num_tickets_retiro_radio                    4 non-null      float64
#  19  num_tickets_mantenimiento_fibra             7 non-null      float64
#  20  encuestas_instal_fibra                      34 non-null     float64
#  21  encuestas_instal_radio                      24 non-null     float64
#  22  encuestas_retiro_fibra                      34 non-null     float64
#  23  encuestas_soporte_fibra                     34 non-null     float64
#  24  encuestas_soporte_radio                     34 non-null     float64
#  25  encuestas_traslado_fibra                    34 non-null     float64
#  26  encuestas_traslado_radio                    8 non-null      float64
#  27  encuestas_retiro_radio                      4 non-null      float64
#  28  encuestas_mantenimiento_fibra               7 non-null      float64
#  29  num_tickets_instal_internet                 34 non-null     float64
#  30  num_tickets_retiro_internet                 34 non-null     float64
#  31  num_tickets_soporte_internet                34 non-null     float64
#  32  num_tickets_traslado_internet               34 non-null     float64
#  33  num_tickets_instal_paquete                  34 non-null     float64
#  34  num_tickets_retiro_paquete                  34 non-null     float64
#  35  num_tickets_soporte_paquete                 34 non-null     float64
#  36  num_tickets_traslado_paquete                34 non-null     float64
#  37  num_tickets_mantenimiento_internet          7 non-null      float64
#  38  tiempo_respuesta_instal_internet            34 non-null     float64
#  39  tiempo_respuesta_retiro_internet            34 non-null     float64
#  40  tiempo_respuesta_soporte_internet           34 non-null     float64
#  41  tiempo_respuesta_traslado_internet          34 non-null     float64
#  42  tiempo_respuesta_instal_paquete             34 non-null     float64
#  43  tiempo_respuesta_retiro_paquete             34 non-null     float64
#  44  tiempo_respuesta_soporte_paquete            34 non-null     float64
#  45  tiempo_respuesta_traslado_paquete           34 non-null     float64
#  46  tiempo_respuesta_mantenimiento_internet     7 non-null      float64
#  47  num_tickets_instal_corporativo              29 non-null     float64
#  48  num_tickets_retiro_corporativo              23 non-null     float64
#  49  num_tickets_soporte_corporativo             34 non-null     float64
#  50  num_tickets_instal_residencial              34 non-null     float64
#  51  num_tickets_retiro_residencial              34 non-null     float64
#  52  num_tickets_soporte_residencial             34 non-null     float64
#  53  num_tickets_traslado_residencial            34 non-null     float64
#  54  num_tickets_traslado_corporativo            17 non-null     float64
#  55  num_tickets_mantenimiento_residencial       7 non-null      float64
#  56  tiempo_respuesta_instal_corporativo         29 non-null     float64
#  57  tiempo_respuesta_retiro_corporativo         23 non-null     float64
#  58  tiempo_respuesta_soporte_corporativo        34 non-null     float64
#  59  tiempo_respuesta_instal_residencial         34 non-null     float64
#  60  tiempo_respuesta_retiro_residencial         34 non-null     float64
#  61  tiempo_respuesta_soporte_residencial        34 non-null     float64
#  62  tiempo_respuesta_traslado_residencial       34 non-null     float64
#  63  tiempo_respuesta_traslado_corporativo       17 non-null     float64
#  64  tiempo_respuesta_mantenimiento_residencial  7 non-null      float64
#  65  per_enc_instal                              34 non-null     float64
#  66  per_enc_retiro                              34 non-null     float64
#  67  per_enc_soporte                             34 non-null     float64
#  68  per_enc_traslado                            34 non-null     float64
# dtypes: float64(67), int64(1), object(1)
# memory usage: 18.5+ KB

# %%
list_of_files = glob.glob(os.path.join(outputs,'Base_tickets*.csv'))
latest_file = max(list_of_files, key=os.path.getctime)
working_data=pd.read_csv(latest_file, low_memory=False)
working_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16876 entries, 0 to 16875
# Data columns (total 60 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_ticket              16876 non-null  int64
#  1   nombre                 16876 non-null  object
#  2   asunto                 16876 non-null  object
#  3   tecnico                16876 non-null  object
#  4   zona                   16832 non-null  object
#  5   abierto_por            16876 non-null  object
#  6   departamento           16876 non-null  object
#  7   categoria              16758 non-null  object
#  8   subcategoria           5567 non-null   object
#  9   fecha_abierto          16876 non-null  object
#  10  fecha_visita           16850 non-null  object
#  11  fecha_cerrado          16876 non-null  object
#  12  mes_crd                16876 non-null  object
#  13  first_day              16876 non-null  object
#  14  tiempo_resolucion      16876 non-null  object
#  15  tiempo_asignacion      16850 non-null  object
#  16  tiempo_atencion        16850 non-null  object
#  17  Id                     16803 non-null  float64
#  18  estado                 16803 non-null  object
#  19  radio                  16803 non-null  float64
#  20  Tipo estrato           16803 non-null  float64
#  21  megas                  12043 non-null  float64
#  22  TV                     16803 non-null  float64
#  23  Telefono               12765 non-null  object
#  24  Movil                  16710 non-null  object
#  25  Correo                 12979 non-null  object
#  26  Zona                   16759 non-null  object
#  27  tarifa                 16803 non-null  float64
#  28  meses_suspendido       16803 non-null  float64
#  29  deuda                  16803 non-null  float64
#  30  ID de registro         16730 non-null  float64
#  31  tecnologia             16803 non-null  object
#  32  tipo_servicio          16803 non-null  object
#  33  tipo_usuario           16803 non-null  object
#  34  _merge                 16876 non-null  object
#  35  tecnico_1              2153 non-null   object
#  36  tecnico_2              402 non-null    object
#  37  conector_mecanico      2153 non-null   float64
#  38  fibra_drop             2153 non-null   float64
#  39  conector_coaxial       2153 non-null   float64
#  40  tensores               2153 non-null   float64
#  41  cable_coaxial          2153 non-null   float64
#  42  cable_utp              2153 non-null   float64
#  43  rjs                    2153 non-null   float64
#  44  deco_tdt               2153 non-null   float64
#  45  splitter_2             2153 non-null   float64
#  46  splitter_3             2153 non-null   float64
#  47  splitter_4             2153 non-null   float64
#  48  mininodos              2153 non-null   float64
#  49  otros                  2153 non-null   float64
#  50  merge2                 16876 non-null  object
#  51  fecha_enc_sat          177 non-null    object
#  52  calificacion_personal  177 non-null    float64
#  53  resolvio               177 non-null    float64
#  54  promoter               177 non-null    float64
#  55  calificacion_servicio  148 non-null    float64
#  56  merge_sat              16876 non-null  object
#  57  encuesta               16876 non-null  bool
#  58  residencial            16876 non-null  int64
#  59  tiempo_resol           16876 non-null  float64
# dtypes: bool(1), float64(27), int64(2), object(30)
# memory usage: 7.6+ MB

# %% [markdown]
# ## Analisis fibra vs radio

# %%
fig, ax= plt.subplots()

working_summary.iloc[-5:].plot(x='mes_crd', y='tiempo_respuesta_soporte_fibra', 
                               kind='line', ax=ax, 
                               color='magenta', grid=True)
working_summary.iloc[-5:].plot(x='mes_crd', y='tiempo_respuesta_instal_fibra', 
                             kind='line', ax=ax, 
                               color='blue', grid=True)
working_summary.iloc[-5:].plot(x='mes_crd', y='tiempo_respuesta_traslado_fibra', 
                             kind='line', ax=ax, 
                               color='grey', grid=True)
working_summary.iloc[-5:].plot(x='mes_crd', y='tiempo_respuesta_retiro_fibra', 
                             kind='line', ax=ax, 
                               color='purple', grid=True)


plt.setp(ax, ylabel='Días', xlabel='', title='Promedio de tiempo de respuesta: fibra')
ax.legend(['Soporte', 'Instalacion', 'Traslado','Retiro'])
plt.tight_layout()
plt.show()

# %%
mask_tecnico=working_data['categoria'].isin(['instal','soporte','retiro','traslado'])

# %%
summary_tix_fibra_radio=working_data.loc[
    mask_tecnico].groupby(
    ['mes_crd', 'tecnologia']).agg(
    num_tix=('id_ticket','nunique')).reset_index().pivot(
    columns='tecnologia',
    values='num_tix', 
    index='mes_crd').reset_index()
summary_tix_fibra_radio.columns=['mes_crd','fibra','radio']
summary_tix_fibra_radio.loc[
    :,'porc_fibra'
]=summary_tix_fibra_radio[
    'fibra']/(summary_tix_fibra_radio[
    'fibra']+summary_tix_fibra_radio[
    'radio'])

summary_tix_fibra_radio.loc[
    :,'porc_radio'
]=summary_tix_fibra_radio[
    'radio']/(summary_tix_fibra_radio[
    'fibra']+summary_tix_fibra_radio[
    'radio'])
summary_tix_fibra_radio.tail()
#print('Durante el último trimestre, el '+str(
#    summary_tix_fibra_radio.iloc[-4:-1][
#        'porc_fibra'].mean())+' de tickets fueron de fibra')
# Out:
#     mes_crd  fibra  radio  porc_fibra  porc_radio
# 29  2024-06    416      7    0.983452    0.016548
# 30  2024-07    463     10    0.978858    0.021142
# 31  2024-08    459     16    0.966316    0.033684
# 32  2024-09    713     15    0.979396    0.020604
# 33  2024-10    379      7    0.981865    0.018135

# %%
fig,ax=plt.subplots()
summary_tix_fibra_radio.iloc[-6:-1,:3].plot.bar(
    'mes_crd','fibra',
    ax=ax, #bottom=base, 
    color='lightseagreen', 
    grid=True)
summary_tix_fibra_radio.iloc[-6:-1,:3].plot.bar(
    'mes_crd','radio',
    ax=ax, bottom=summary_tix_fibra_radio.iloc[-6:-1,:3]['fibra'], 
    color='tomato', 
    grid=True)

plt.tight_layout()
plt.show()

# %%
fig, ax=plt.subplots()

working_summary.iloc[-6:].plot(
    x='mes_crd', y='tiempo_respuesta_soporte_radio', 
    kind='line', ax=ax, 
    color='magenta', grid=True, linestyle='--')

working_summary.iloc[-6:].plot(
    x='mes_crd', y='tiempo_respuesta_instal_radio', 
                               kind='line', ax=ax, 
                               color='blue', grid=True, linestyle='--')

working_summary.iloc[-6:].plot(
    x='mes_crd', y='tiempo_respuesta_traslado_radio', 
                               kind='line', ax=ax, 
                               color='grey', grid=True, linestyle='--')

working_summary.iloc[-6:].plot(
    x='mes_crd', y='tiempo_respuesta_retiro_radio', 
                               kind='line', ax=ax, 
                               color='purple', grid=True, linestyle='--')

plt.setp(ax, ylabel='Días', xlabel='', title='Promedio de tiempo de respuesta: radio')
ax.legend(['Soporte', 'Instalacion', 'Traslado','Retiro'])
plt.tight_layout()
plt.show()
