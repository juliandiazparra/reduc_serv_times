# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
import matplotlib.ticker as mtick
import os
import platform

# %%
if platform.system()=='Windows': 
    #Directorios Windows
    os.chdir(
        r"G:\.shortcut-targets-by-id\120bUa35y3FJzvumWahpOx1qS9I6TIrhb\GIGANAV")

if platform.system()=='Darwin':
    os.chdir(
        '/Users/juliandiazparra/Library/CloudStorage/GoogleDrive-julian.adiaz@hotmail.com/Mi unidad/Negocios/Familiar/GIGANAV')

folder=os.getcwd()
data=os.path.join(folder,'Datos')
provisiones=os.path.join(data,'Provisiones')
facturas=os.path.join(data,'Facturas')
tickets=os.path.join(data,'Tickets')
usuarios=os.path.join(data,'Usuarios')
egresos=os.path.join(data,'Egresos')
transacciones=os.path.join(data,'Transacciones')
analisis=os.path.join(folder,'Operacion/Analisis')
resultados=os.path.join(analisis,'Resultados')
bases=os.path.join(analisis,'Bases_analisis')
outputs=os.path.join(analisis,'Output')
plots=os.path.join(outputs,'Gráficos')
usuarios_clean=os.path.join(bases,'Usuarios')
transac_clean=os.path.join(bases,'Transacciones')
tickets_clean=os.path.join(bases,'Tickets')
facturas_clean=os.path.join(bases,'Facturas')
egresos_clean=os.path.join(bases,'Egresos')
working=os.path.join(bases,'Bases_trabajo')
codigo=os.path.join(folder,'Operacion/Analisis/Código')
conciliaciones=os.path.join(folder,'Operacion/Operativo/Administrativo/Conciliaciones')

# %%
#Importo archivo de tickets
filepath=os.path.join(tickets,'Lista de Ticket Cerrados')
lista_tickets=pd.read_csv(filepath+'.csv')
lista_tickets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23984 entries, 0 to 23983
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Nº             23984 non-null  int64
#  1   Departamento   23984 non-null  object
#  2   Remitente      23984 non-null  object
#  3   Asunto         23984 non-null  object
#  4   Técnico        23984 non-null  object
#  5   Fecha          23984 non-null  object
#  6   Fecha visita   23938 non-null  object
#  7   Coordenadas    1687 non-null   object
#  8   Estado         23984 non-null  object
#  9   Ubicación      23452 non-null  object
#  10  Dirección      23466 non-null  object
#  11  Movil          23284 non-null  object
#  12  Teléfono       17309 non-null  object
#  13  F. Cerrado     23984 non-null  object
#  14  Abierto por    23984 non-null  object
#  15  Última Rspta.  23984 non-null  object
#  16  Unnamed: 16    0 non-null      float64
# dtypes: float64(1), int64(1), object(15)
# memory usage: 3.1+ MB

# %%
lista_tickets.head()
# Out:
#       Nº     Departamento                      Remitente  \
# 0  24920      Cuadrilla 1    JAIRO ARMANDO PLAZA HERRERA
# 1  24911        Comercial     DEGLYS LORENA BELENO GOMEZ
# 2  24907  Soporte técnico  CAMPO EDUARDO IBARRA MENDIETA
# 3  24905  Soporte técnico     SLENDY MARIA BLANCO NIEVES
# 4  24903  Soporte técnico           MARIBEL ALVAREZ MELO
#
#                               Asunto                   Técnico  \
# 0  Falla del servicio (sin servicio)  LEONARDO QUEZADA RAMIREZ
# 1                     Cambio de Plan               No asignado
# 2               Soporte Sin Servicio   ESNEIDER GARCIA BARAJAS
# 3               Cambio de Contraseña  KAROLINA GUERRERO PRINCE
# 4               Soporte Sin Servicio   ESNEIDER GARCIA BARAJAS
#
#                     Fecha         Fecha visita Coordenadas   Estado  \
# 0  08/10/2024 11:32:05 am  08/10/2024  (TARDE)         NaN  CERRADO
# 1  08/10/2024 10:15:59 am  08/10/2024  (TARDE)         NaN  CERRADO
# 2  08/10/2024 09:11:45 am  08/10/2024  (TARDE)         NaN  CERRADO
# 3  08/10/2024 08:55:43 am  08/10/2024  (TARDE)         NaN  CERRADO
# 4  08/10/2024 08:40:52 am  08/10/2024  (TARDE)         NaN  CERRADO
#
#                    Ubicación  \
# 0                  BETANCURT
# 1                  LOS PINOS
# 2          CGTO LA PEDREGOSA
# 3  ASENTAMIENTO LIBERTADORES
# 4         ALTOS DEL PROGRESO
#
#                                           Dirección       Movil    Teléfono  \
# 0                          CLL 2B N 15 36 BETANCURT  3162224487         NaN
# 1                          CLL 1B N 6B 11 LOS PINOS  3168873475         NaN
# 2                        CLL 0A N 2 363 SAN ANTONIO  3162417512  3185117674
# 3              CLL 4 MANZ H LOTE 7 LOS LIBERTADORES  3184535004  3186839192
# 4  CLL 1C N 2D 34 MANZ Q CASA 17 ALTOS DEL PROGRESO  3174973943  3186334291
#
#             F. Cerrado Abierto por           Última Rspta.  Unnamed: 16
# 0  08/10/2024 12:36:02     TECNICO   1728408962Hace 1 Hora          NaN
# 1  08/10/2024 10:17:21   KGUERRERO  1728400641Hace 3 Horas          NaN
# 2  08/10/2024 11:21:21   KGUERRERO  1728404481Hace 2 Horas          NaN
# 3  08/10/2024 08:56:04   KGUERRERO  1728395764Hace 5 Horas          NaN
# 4  08/10/2024 10:22:58   KGUERRERO  1728400978Hace 3 Horas          NaN

# %%
base_tickets=lista_tickets.iloc[:, [0, 1, 2, 3, 4, 5, 9, 12, 13]]
base_tickets.head()
# Out:
#       Nº     Departamento                      Remitente  \
# 0  24920      Cuadrilla 1    JAIRO ARMANDO PLAZA HERRERA
# 1  24911        Comercial     DEGLYS LORENA BELENO GOMEZ
# 2  24907  Soporte técnico  CAMPO EDUARDO IBARRA MENDIETA
# 3  24905  Soporte técnico     SLENDY MARIA BLANCO NIEVES
# 4  24903  Soporte técnico           MARIBEL ALVAREZ MELO
#
#                               Asunto                   Técnico  \
# 0  Falla del servicio (sin servicio)  LEONARDO QUEZADA RAMIREZ
# 1                     Cambio de Plan               No asignado
# 2               Soporte Sin Servicio   ESNEIDER GARCIA BARAJAS
# 3               Cambio de Contraseña  KAROLINA GUERRERO PRINCE
# 4               Soporte Sin Servicio   ESNEIDER GARCIA BARAJAS
#
#                     Fecha                  Ubicación    Teléfono  \
# 0  08/10/2024 11:32:05 am                  BETANCURT         NaN
# 1  08/10/2024 10:15:59 am                  LOS PINOS         NaN
# 2  08/10/2024 09:11:45 am          CGTO LA PEDREGOSA  3185117674
# 3  08/10/2024 08:55:43 am  ASENTAMIENTO LIBERTADORES  3186839192
# 4  08/10/2024 08:40:52 am         ALTOS DEL PROGRESO  3186334291
#
#             F. Cerrado
# 0  08/10/2024 12:36:02
# 1  08/10/2024 10:17:21
# 2  08/10/2024 11:21:21
# 3  08/10/2024 08:56:04
# 4  08/10/2024 10:22:58

# %%
base_tickets['Asunto'].value_counts()
# Out:
# Asunto
# SIN SERVICIO                       2188
# SERVICIO LENTO                     1072
# INSTALACION DE SERVICIO            1047
# TRASLADO DE SERVICIO               1046
# RETIRAR SERVICIO                   1003
#                                    ...
# TRASLADO DE SERVICIO- SABADO          1
# SIN SERVICIO DE TV- 5:00 PM           1
# PEGAR ROUTER Y SERVICIO LENTO         1
# TRASLADO DE SERVICIO - EL LUNES       1
# instalacion router                    1
# Name: count, Length: 1991, dtype: int64

# %%
#Creo categorias
#Tecnicos
base_tickets.loc[:,'instal']=base_tickets['Asunto'].str.contains('instal', 
                                                                   case=False)*1
base_tickets.loc[:,'soporte']=base_tickets['Asunto'].str.contains(
    'soporte|sin servicio|revisar|lento|intermiten|potencia|servicio tecnico|ocultar|pegar|alinear|configurar|clave]equipo|finalizar', 
                                                                    case=False)*1
base_tickets.loc[:,'traslado']=base_tickets['Asunto'].str.contains('trasla|transla', 
                                                                     case=False)*1
base_tickets.loc[:,'retiro']=base_tickets['Asunto'].str.contains('retir', 
                                                                   case=False)*1
base_tickets.loc[:,'mantenimiento']=base_tickets['Asunto'].str.contains('mantenimien', 
                                                                          case=False)*1

#Comercial
base_tickets.loc[:,'facturacion']=base_tickets['Asunto'].str.contains('facturacion|factura|editar', 
                                                                        case=False)*1
base_tickets.loc[:,'cambio_plan']=base_tickets['Asunto'].str.contains(r'^(?=.*cambio)(?=.*plan)', 
                                                                        case=False)*1
base_tickets.loc[:,'suspendido']=base_tickets['Asunto'].str.contains('suspend', case=False)*1

#Identificadores
base_tickets.loc[:,'tv']=base_tickets['Asunto'].str.contains('tv', 
                                                               case=False)*1
base_tickets.loc[:, 'llamada']=base_tickets['Asunto'].str.contains('llamada', 
                                                                     case=False)*1
# Out:
# /var/folders/_1/wccngqsd417dbsr4pcv82tj80000gn/T/ipykernel_2488/793570207.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_tickets.loc[:,'instal']=base_tickets['Asunto'].str.contains('instal',
# /var/folders/_1/wccngqsd417dbsr4pcv82tj80000gn/T/ipykernel_2488/793570207.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_tickets.loc[:,'soporte']=base_tickets['Asunto'].str.contains(
# /var/folders/_1/wccngqsd417dbsr4pcv82tj80000gn/T/ipykernel_2488/793570207.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_tickets.loc[:,'traslado']=base_tickets['Asunto'].str.contains('trasla|transla',
# /var/folders/_1/wccngqsd417dbsr4pcv82tj80000gn/T/ipykernel_2488/793570207.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_tickets.loc[:,'retiro']=base_tickets['Asunto'].str.contains('retir',
# /var/folders/_1/wccngqsd417dbsr4pcv82tj80000gn/T/ipykernel_2488/793570207.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_tickets.loc[:,'mantenimiento']=base_tickets['Asunto'].str.contains('mantenimien',
# /var/folders/_1/wccngqsd417dbsr4pcv82tj80000gn/T/ipykernel_2488/793570207.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_tickets.loc[:,'facturacion']=base_tickets['Asunto'].str.contains('facturacion|factura|editar',
# /var/folders/_1/wccngqsd417dbsr4pcv82tj80000gn/T/ipykernel_2488/793570207.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_tickets.loc[:,'cambio_plan']=base_tickets['Asunto'].str.contains(r'^(?=.*cambio)(?=.*plan)',

# %%
#Creo variable de categoria
#soporte
base_tickets.loc[(base_tickets['soporte']==1),'categoria']='Soporte'

#instal
base_tickets.loc[(base_tickets['instal']==1) & 
                  (base_tickets['soporte']==0),'categoria']='Instalacion'
#Retiro
base_tickets.loc[(base_tickets['retiro']==1) & 
                  (base_tickets['soporte']==0),'categoria']='Retiro'
#Traslado
base_tickets.loc[(base_tickets['traslado']==1), 'categoria']='Traslado'

#Cambio de plan
base_tickets.loc[(base_tickets['cambio_plan']==1), 'categoria']='Cambio de plan'
base_tickets.loc[(base_tickets['facturacion']==1), 'categoria']='Facturacion'
base_tickets.loc[(base_tickets['suspendido']==1), 'categoria']='Suspendido'

# %%
base_tickets['categoria'].value_counts()
# Out:
# categoria
# Soporte           9867
# Instalacion       3936
# Retiro            2410
# Cambio de plan    1792
# Facturacion       1698
# Traslado          1567
# Suspendido         102
# Name: count, dtype: int64

# %%
#Miro formatos de fechas
lista_tickets[['Fecha', 'F. Cerrado']]
# Out:
#                         Fecha           F. Cerrado
# 0      08/10/2024 11:32:05 am  08/10/2024 12:36:02
# 1      08/10/2024 10:15:59 am  08/10/2024 10:17:21
# 2      08/10/2024 09:11:45 am  08/10/2024 11:21:21
# 3      08/10/2024 08:55:43 am  08/10/2024 08:56:04
# 4      08/10/2024 08:40:52 am  08/10/2024 10:22:58
# ...                       ...                  ...
# 23979  13/03/2018 09:23:34 am  14/03/2018 08:46:00
# 23980  06/03/2018 04:22:58 pm  21/03/2018 16:48:03
# 23981  06/03/2018 04:18:57 pm  13/04/2018 08:24:00
# 23982  05/03/2018 11:48:36 am  14/03/2018 08:46:00
# 23983  05/03/2018 11:36:51 am  06/03/2018 15:04:00
#
# [23984 rows x 2 columns]

# %%
#Doy formato fechas
#Fecha abierto
base_tickets.loc[:,'fecha_abierto'] = pd.to_datetime(
    base_tickets['Fecha'], format='%d/%m/%Y %I:%M:%S %p')
#Fecha cerrado
base_tickets.loc[:,'fecha_cerrado'] = pd.to_datetime( 
    base_tickets['F. Cerrado'], format='%d/%m/%Y %H:%M:%S')

# %%
#Miro variables relevantes
base_tickets.columns
# Out:
# Index(['Nº', 'Departamento', 'Remitente', 'Asunto', 'Técnico', 'Fecha',
#        'Ubicación', 'Teléfono', 'F. Cerrado', 'instal', 'soporte', 'traslado',
#        'retiro', 'mantenimiento', 'facturacion', 'cambio_plan', 'suspendido',
#        'tv', 'llamada', 'categoria', 'fecha_abierto', 'fecha_cerrado'],
#       dtype='object')

# %%
#Depuro variables
tickets_df=base_tickets.loc[:, list(base_tickets.columns[np.r_[0:5, 6, 8:22]])]
tickets_df.columns
# Out:
# Index(['Nº', 'Departamento', 'Remitente', 'Asunto', 'Técnico', 'Ubicación',
#        'F. Cerrado', 'instal', 'soporte', 'traslado', 'retiro',
#        'mantenimiento', 'facturacion', 'cambio_plan', 'suspendido', 'tv',
#        'llamada', 'categoria', 'fecha_abierto', 'fecha_cerrado'],
#       dtype='object')

# %%
#Renombro variables
tickets_df.columns=['id_ticket', 'departamento', 'nombre', 
 'asunto', 'tecnico', 'zona', 
 'abierto_por'] +list(base_tickets.columns[9:])
tickets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23984 entries, 0 to 23983
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id_ticket      23984 non-null  int64
#  1   departamento   23984 non-null  object
#  2   nombre         23984 non-null  object
#  3   asunto         23984 non-null  object
#  4   tecnico        23984 non-null  object
#  5   zona           23452 non-null  object
#  6   abierto_por    23984 non-null  object
#  7   instal         23984 non-null  int64
#  8   soporte        23984 non-null  int64
#  9   traslado       23984 non-null  int64
#  10  retiro         23984 non-null  int64
#  11  mantenimiento  23984 non-null  int64
#  12  facturacion    23984 non-null  int64
#  13  cambio_plan    23984 non-null  int64
#  14  suspendido     23984 non-null  int64
#  15  tv             23984 non-null  int64
#  16  llamada        23984 non-null  int64
#  17  categoria      21372 non-null  object
#  18  fecha_abierto  23984 non-null  datetime64[ns]
#  19  fecha_cerrado  23984 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(11), object(7)
# memory usage: 3.7+ MB

# %%
#Guardo la base como csv
years=list(tickets_df['fecha_cerrado'].dt.year.unique())
for i in years:
    file_path=os.path.join(tickets_clean, 'Tickets_'+str(i))
    mask_year=pd.to_datetime(tickets_df['fecha_cerrado']).dt.year==i
    tickets_df.loc[mask_year].to_excel(file_path+'.xlsx', index=False)
    tickets_df.loc[mask_year].to_csv(file_path+'.csv', index=False)

# %%
#Validación
tickets_df['fecha_cerrado'].max()
# Out:
# Timestamp('2024-10-08 13:49:26')
