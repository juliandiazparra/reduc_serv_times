# %%
#import streamlit as st
#import pandas as pd
#import altair as alt
#import plotly.express as px

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
import matplotlib.ticker as mtick
import os
import platform
import glob

# %%
if platform.system()=='Windows': 
    #Directorios Windows
    os.chdir(
        r"G:\.shortcut-targets-by-id\120bUa35y3FJzvumWahpOx1qS9I6TIrhb\GIGANAV")

if platform.system()=='Darwin':
    os.chdir(
        '/Users/juliandiazparra/Library/CloudStorage/GoogleDrive-julian.adiaz@hotmail.com/Mi unidad/Negocios/Familiar/GIGANAV')

folder=os.getcwd()
data=os.path.join(folder,'Datos')
provisiones=os.path.join(data,'Provisiones')
facturas=os.path.join(data,'Facturas')
tickets=os.path.join(data,'Tickets')
usuarios=os.path.join(data,'Usuarios')
egresos=os.path.join(data,'Egresos')
transacciones=os.path.join(data,'Transacciones')
analisis=os.path.join(folder,'Operacion/Analisis')
resultados=os.path.join(analisis,'Resultados')
bases=os.path.join(analisis,'Bases_analisis')
outputs=os.path.join(analisis,'Outputs')
plots=os.path.join(outputs,'Gráficos')
usuarios_clean=os.path.join(bases,'Usuarios')
transac_clean=os.path.join(bases,'Transacciones')
tickets_clean=os.path.join(bases,'Tickets')
facturas_clean=os.path.join(bases,'Facturas')
egresos_clean=os.path.join(bases,'Egresos')
working=os.path.join(bases,'Bases_trabajo')
codigo=os.path.join(folder,'Operacion/Analisis/Código')
conciliaciones=os.path.join(folder,'Operacion/Operativo/Administrativo/Conciliaciones')

# %% [markdown]
# ## Importación base de trabajo

# %%
list_of_files = glob.glob(os.path.join(outputs,'Resumen_mes_categorias*.csv'))
latest_file = max(list_of_files, key=os.path.getctime)
working_summary=pd.read_csv(latest_file, low_memory=False)
working_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 62 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Unnamed: 0                                33 non-null     int64
#  1   mes_crd                                   33 non-null     object
#  2   tiempo_respuesta_Instalacion_fibra        33 non-null     float64
#  3   tiempo_respuesta_Instalacion_radio        23 non-null     float64
#  4   tiempo_respuesta_Retiro_fibra             33 non-null     float64
#  5   tiempo_respuesta_Soporte_fibra            33 non-null     float64
#  6   tiempo_respuesta_Soporte_radio            33 non-null     float64
#  7   tiempo_respuesta_Traslado_fibra           33 non-null     float64
#  8   tiempo_respuesta_Traslado_radio           8 non-null      float64
#  9   tiempo_respuesta_Retiro_radio             7 non-null      float64
#  10  num_tickets_Instalacion_fibra             33 non-null     float64
#  11  num_tickets_Instalacion_radio             23 non-null     float64
#  12  num_tickets_Retiro_fibra                  33 non-null     float64
#  13  num_tickets_Soporte_fibra                 33 non-null     float64
#  14  num_tickets_Soporte_radio                 33 non-null     float64
#  15  num_tickets_Traslado_fibra                33 non-null     float64
#  16  num_tickets_Traslado_radio                8 non-null      float64
#  17  num_tickets_Retiro_radio                  7 non-null      float64
#  18  encuestas_Instalacion_fibra               33 non-null     float64
#  19  encuestas_Instalacion_radio               23 non-null     float64
#  20  encuestas_Retiro_fibra                    33 non-null     float64
#  21  encuestas_Soporte_fibra                   33 non-null     float64
#  22  encuestas_Soporte_radio                   33 non-null     float64
#  23  encuestas_Traslado_fibra                  33 non-null     float64
#  24  encuestas_Traslado_radio                  8 non-null      float64
#  25  encuestas_Retiro_radio                    7 non-null      float64
#  26  num_tickets_Instalacion_internet          33 non-null     float64
#  27  num_tickets_Retiro_internet               33 non-null     float64
#  28  num_tickets_Soporte_internet              33 non-null     float64
#  29  num_tickets_Traslado_internet             33 non-null     float64
#  30  num_tickets_Instalacion_paquete           33 non-null     float64
#  31  num_tickets_Retiro_paquete                33 non-null     float64
#  32  num_tickets_Soporte_paquete               33 non-null     float64
#  33  num_tickets_Traslado_paquete              33 non-null     float64
#  34  tiempo_respuesta_Instalacion_internet     33 non-null     float64
#  35  tiempo_respuesta_Retiro_internet          33 non-null     float64
#  36  tiempo_respuesta_Soporte_internet         33 non-null     float64
#  37  tiempo_respuesta_Traslado_internet        33 non-null     float64
#  38  tiempo_respuesta_Instalacion_paquete      33 non-null     float64
#  39  tiempo_respuesta_Retiro_paquete           33 non-null     float64
#  40  tiempo_respuesta_Soporte_paquete          33 non-null     float64
#  41  tiempo_respuesta_Traslado_paquete         33 non-null     float64
#  42  num_tickets_Instalacion_corporativo       33 non-null     float64
#  43  num_tickets_Retiro_corporativo            24 non-null     float64
#  44  num_tickets_Soporte_corporativo           33 non-null     float64
#  45  num_tickets_Instalacion_residencial       33 non-null     float64
#  46  num_tickets_Retiro_residencial            33 non-null     float64
#  47  num_tickets_Soporte_residencial           33 non-null     float64
#  48  num_tickets_Traslado_residencial          33 non-null     float64
#  49  num_tickets_Traslado_corporativo          19 non-null     float64
#  50  tiempo_respuesta_Instalacion_corporativo  33 non-null     float64
#  51  tiempo_respuesta_Retiro_corporativo       24 non-null     float64
#  52  tiempo_respuesta_Soporte_corporativo      33 non-null     float64
#  53  tiempo_respuesta_Instalacion_residencial  33 non-null     float64
#  54  tiempo_respuesta_Retiro_residencial       33 non-null     float64
#  55  tiempo_respuesta_Soporte_residencial      33 non-null     float64
#  56  tiempo_respuesta_Traslado_residencial     33 non-null     float64
#  57  tiempo_respuesta_Traslado_corporativo     19 non-null     float64
#  58  per_enc_Instalacion                       33 non-null     float64
#  59  per_enc_Retiro                            33 non-null     float64
#  60  per_enc_Soporte                           33 non-null     float64
#  61  per_enc_Traslado                          33 non-null     float64
# dtypes: float64(60), int64(1), object(1)
# memory usage: 16.1+ KB

# %%
list_of_files = glob.glob(os.path.join(outputs,'Base_tickets*.csv'))
latest_file = max(list_of_files, key=os.path.getctime)
working_data=pd.read_csv(latest_file, low_memory=False)
working_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15058 entries, 0 to 15057
# Data columns (total 70 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             15058 non-null  int64
#  1   id_ticket              15058 non-null  int64
#  2   departamento           15058 non-null  object
#  3   nombre                 15058 non-null  object
#  4   asunto                 15058 non-null  object
#  5   tecnico                15058 non-null  object
#  6   zona                   15021 non-null  object
#  7   abierto_por            15058 non-null  object
#  8   instal                 15058 non-null  int64
#  9   soporte                15058 non-null  int64
#  10  traslado               15058 non-null  int64
#  11  retiro                 15058 non-null  int64
#  12  mantenimiento          15058 non-null  int64
#  13  facturacion            15058 non-null  int64
#  14  cambio_plan            15058 non-null  int64
#  15  suspendido             15058 non-null  int64
#  16  tv                     15058 non-null  int64
#  17  llamada                15058 non-null  int64
#  18  categoria              14225 non-null  object
#  19  fecha_abierto          15058 non-null  object
#  20  fecha_cerrado          15058 non-null  object
#  21  mes_crd                15058 non-null  object
#  22  first_day              15058 non-null  object
#  23  tiempo_resolucion      15058 non-null  object
#  24  cat_tecnico            14225 non-null  float64
#  25  comercial              14225 non-null  float64
#  26  Id                     14838 non-null  float64
#  27  estado                 14838 non-null  object
#  28  radio                  14838 non-null  float64
#  29  Tipo estrato           14838 non-null  float64
#  30  megas                  14838 non-null  float64
#  31  TV                     14838 non-null  float64
#  32  Telefono               11136 non-null  object
#  33  Movil                  14763 non-null  object
#  34  Correo                 11341 non-null  object
#  35  Zona                   14797 non-null  object
#  36  tarifa                 14838 non-null  float64
#  37  Deuda actual           3684 non-null   object
#  38  ID de registro         14830 non-null  float64
#  39  meses_suspendido       1001 non-null   float64
#  40  deuda                  1001 non-null   float64
#  41  tecnologia             14838 non-null  object
#  42  tipo_servicio          14838 non-null  object
#  43  tipo_usuario           14838 non-null  object
#  44  _merge                 15058 non-null  object
#  45  tecnico_1              1609 non-null   float64
#  46  tecnico_2              1609 non-null   float64
#  47  conector_mecanico      1609 non-null   float64
#  48  fibra_drop             1609 non-null   float64
#  49  conector_coaxial       1609 non-null   float64
#  50  tensores               1609 non-null   float64
#  51  cable_coaxial          1609 non-null   float64
#  52  cable_utp              1609 non-null   float64
#  53  rjs                    1609 non-null   float64
#  54  deco_tdt               1609 non-null   float64
#  55  splitter_2             1609 non-null   float64
#  56  splitter_3             1609 non-null   float64
#  57  splitter_4             1609 non-null   float64
#  58  mininodos              1609 non-null   float64
#  59  otros                  1609 non-null   float64
#  60  merge2                 15058 non-null  object
#  61  fecha_enc_sat          78 non-null     object
#  62  calificacion_personal  78 non-null     float64
#  63  resolvio               78 non-null     float64
#  64  promoter               78 non-null     float64
#  65  calificacion_servicio  49 non-null     float64
#  66  merge_sat              15058 non-null  object
#  67  encuesta               15058 non-null  bool
#  68  residencial            15058 non-null  int64
#  69  tiempo_resol           15058 non-null  float64
# dtypes: bool(1), float64(31), int64(13), object(25)
# memory usage: 7.9+ MB

# %% [markdown]
# ## Panel resumen Coordinador

# %%
#Hago resumen Coordinador
working_summary.loc[
    :,'per_encuestas'
]=working_summary.loc[
    :,['per_enc_Instalacion',
       'per_enc_Soporte']].mean(axis=1)

# %%
#Indicadores
valor_variable=380000
indicadores_tecnicos=pd.DataFrame()
indicadores_tecnicos.loc[
    :,'Indicadores']=['tiempo_respuesta_Soporte_fibra',
        'tiempo_respuesta_Instalacion_fibra', 
        'per_encuestas']
indicadores_tecnicos.loc[
    :,'Peso'
]=[.4,.4,.2]
indicadores_tecnicos.loc[
    :,'Valor'
]=indicadores_tecnicos[
    'Peso']*valor_variable

indicadores_tecnicos
# Out:
#                           Indicadores  Peso     Valor
# 0      tiempo_respuesta_Soporte_fibra   0.4  152000.0
# 1  tiempo_respuesta_Instalacion_fibra   0.4  152000.0
# 2                       per_encuestas   0.2   76000.0

# %%
mes=list(working_summary.loc[pd.to_datetime(
    working_summary['mes_crd']).dt.strftime(
    '%Y')==datetime.today().strftime(
    '%Y'), 'mes_crd'].unique())

filepath=os.path.join(
    outputs,
    'Indicadores_coordinador_'+datetime.today().strftime('%Y')+'.xlsx')

writer = pd.ExcelWriter(filepath, 
                        engine = 'xlsxwriter') 

for m in mes:
    resumen_coordinador=pd.DataFrame()
    resumen_coordinador.loc[
        :,m
    ]=working_summary.loc[
        working_summary['mes_crd']==m, [
            'mes_crd', 
            'tiempo_respuesta_Soporte_fibra',
            'tiempo_respuesta_Instalacion_fibra', 
            'per_encuestas'
        ]
    ].iloc[-1].iloc[1:]

    resumen_coordinador.loc[
        :,'Meta'
    ]=[3.5,3.5,.7]

    resumen_coordinador.loc[
        :,'% cumplimiento'
    ]=1-((resumen_coordinador[
        m]-resumen_coordinador[
        'Meta'])/resumen_coordinador[
        'Meta'])

    resumen_coordinador.loc[
        resumen_coordinador.index=='per_encuestas', 
        '% cumplimiento']=resumen_coordinador[
        m]/resumen_coordinador['Meta']

    resumen_coordinador.reset_index(inplace=True)
    resumen_coordinador.rename(
        columns={'index':'Indicadores'}, inplace=True)
    resumen_coordinador=resumen_coordinador.merge(
        indicadores_tecnicos[['Indicadores','Valor']], 
        on='Indicadores')

    #Creo compensaciones
    resumen_coordinador.loc[
        :,'Compensacion']=np.select(
        [(resumen_coordinador['% cumplimiento']<.8)] ,[0],
        default=(resumen_coordinador[
            '% cumplimiento']*resumen_coordinador[
            'Valor']))
    
    resumen_coordinador.to_excel(
                writer, sheet_name=m, index=False)
    
writer.close()

# %%
working_summary[['mes_crd','tiempo_respuesta_Instalacion_fibra',
                 'tiempo_respuesta_Instalacion_fibra','per_encuestas']].tail()
# Out:
#     mes_crd  tiempo_respuesta_Instalacion_fibra  \
# 28  2024-05                            4.939924
# 29  2024-06                            3.722982
# 30  2024-07                            5.723410
# 31  2024-08                            3.213869
# 32  2024-09                            2.478820
#
#     tiempo_respuesta_Instalacion_fibra  per_encuestas
# 28                            4.939924       0.521541
# 29                            3.722982       0.688525
# 30                            5.723410       0.444388
# 31                            3.213869       0.440523
# 32                            2.478820       0.499849
